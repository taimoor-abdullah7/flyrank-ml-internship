# %% [markdown]
# # ML-02 — Research Question and Provisional Lane
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/taimoor-abdullah7/flyrank-ml-internship/blob/main/work/notebooks/w01_research_question.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane (or freestyle) and why
#
# *Name your lane — or say 'freestyle' and describe your own question. One short paragraph: why this one?*

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.
#I chose Refresh / Content Opportunity Scoring as my provisional lane. The goal is to identify which content pages should be reviewed first for improvement based on observable search and engagement signals. I selected this lane because it builds naturally on the starter project, where we already explored refresh scoring and ranking models. This project focuses on helping prioritize limited review resources rather than simply training a machine learning model, making it a practical decision-support problem.

# %% [markdown]
# ## 2. The question: decision, action, cost of a wrong call
#
# *What decision does your work improve? Who acts on it? What does a wrong recommendation cost?*

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.
#Research question: Which content pages should be reviewed first based on observable search and engagement signals?

#Decision: Decide which pages should be prioritized for review or refresh.

#Action: A content reviewer or SEO team reviews the highest-ranked pages first and decides whether to update, expand, monitor, or improve them.

#Cost of a wrong recommendation:** If the system recommends the wrong pages, valuable time may be spent reviewing low-impact content while more important pages are missed. This can reduce the effectiveness of the review process and delay improvements to high-priority content.

# %% [markdown]
# ## 3. Quick look at the data (2-3 real numbers)
#
# *Load the starter CSV below and show 2-3 real numbers that make your lane look worth the next 7 weeks.*

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.
import pandas as pd

# Load the starter dataset
df = pd.read_csv("data/raw/content_refresh_anonymized.csv")

print("Rows:", len(df))
print("Columns:", len(df.columns))
print("Pages with declining trend:", (df["trend_direction"] == "down").sum())

#The starter dataset contains **30,000** content records and **44** features. Out of these, **16,262** pages show a declining trend. This suggests that a large portion of the content may benefit from review or refresh, making the Refresh / Content Opportunity Scoring lane a useful decision-support problem to explore over the next seven weeks.
# Out:
# Rows: 30000
# Columns: 44
# Pages with declining trend: 16262

# %% [markdown]
# ## 4. Careful words: what I can and can't claim
#
# *Write what your work will be able to say (observed, directional, decision-support) — and what it never will (causal proof, 'predicting Google').*

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.
#This project can identify patterns in the available data and provide decision-support for prioritizing which pages may need review or refresh. Any recommendations are based on observed data and should be used to support human decisions. This work cannot prove that refreshing a page will improve performance, predict Google's ranking decisions, or establish cause-and-effect relationships.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [x] Every section above is filled — markdown thinking AND the code that backs it
# - [x] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [x] No client names, URLs, or private queries anywhere
# - [x] My claims use careful words: observed, measured, directional, decision-support
# - [x] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
